# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('database.csv', sep=';',decimal=",", encoding="ISO-8859-1")

# %%
df.head()
# Out:
#    dat_compra  num_mes  num_ano flg_mkt_place  cod_cliente  cod_prod  \
# 0  31/01/2017        1     2017           SIM     28641444     36830
# 1  02/02/2017        2     2017           SIM     27155083     36830
# 2  03/02/2017        2     2017           SIM     27162068     36830
# 3  09/02/2017        2     2017           SIM     27200198     36830
# 4  20/02/2017        2     2017           SIM     27284737     36830
#
#   cod_depto  val_prod  qtd_pecas
# 0    6qski6     177.9        1.0
# 1    6qski6     177.9        1.0
# 2    6qski6     177.9        1.0
# 3    6qski6     177.9        1.0
# 4    6qski6     177.9        1.0

# %%
df.describe()
# Out:
#             num_mes    num_ano   cod_cliente      cod_prod      val_prod  \
# count  6.844093e+06  6844093.0  6.844093e+06  6.844093e+06  6.844093e+06
# mean   6.454302e+00     2017.0  2.763803e+07  8.791951e+07  8.333605e+02
# std    3.326155e+00        0.0  3.694435e+06  3.624758e+07  1.049297e+03
# min    1.000000e+00     2017.0  1.466750e+05  3.683000e+04  1.000000e-02
# 25%    4.000000e+00     2017.0  2.619668e+07  7.581071e+07  1.541600e+02
# 50%    6.000000e+00     2017.0  2.752631e+07  9.793525e+07  4.959400e+02
# 75%    1.000000e+01     2017.0  2.939176e+07  1.163800e+08  1.161840e+03
# max    1.200000e+01     2017.0  3.575389e+07  1.410880e+08  9.518095e+04
#
#           qtd_pecas
# count  6.844091e+06
# mean   1.129345e+00
# std    6.527945e-01
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    1.000000e+00
# 75%    1.000000e+00
# max    9.900000e+01

# %%
df['cod_cliente'].value_counts()
# Out:
# 29769515    2452
# 35313361     951
# 30978522     618
# 28057750     431
# 26070263     430
# 34739318     321
# 28166487     306
# 25215965     295
# 27730167     291
# 34848044     267
# 28997791     248
# 27464334     244
# 30207522     244
# 26320545     243
# 26673298     241
# 35334602     222
# 33285491     220
# 24246844     219
# 26268756     217
# 28892158     215
# 25548688     214
# 26215621     212
# 26971947     210
# 27845866     201
# 28891012     198
# 28932978     197
# 28146302     187
# 29043514     174
# 25967730     167
# 25689372     167
#             ...
# 35015174       1
# 34179582       1
# 26073460       1
# 26069366       1
# 25852288       1
# 21655937       1
# 26948963       1
# 27315890       1
# 34216332       1
# 30073235       1
# 25917856       1
# 25909668       1
# 34294182       1
# 25921982       1
# 25700810       1
# 29884879       1
# 29942227       1
# 29934039       1
# 29925851       1
# 25725406       1
# 25782754       1
# ...

# %%
df3=df['cod_depto'].value_counts()

# %%
df=pd.to_csv('nome_do_arquivo_para_salvar.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-691ab5c41cd0> in <module>()
# ----> 1 df=pd.to_csv('nome_do_arquivo_para_salvar.csv')
#
# AttributeError: module 'pandas' has no attribute 'to_csv'

# %%
df.max()
# Out:
# dat_compra     31/10/2017
# num_mes                12
# num_ano              2017
# cod_cliente      35753888
# cod_prod        141087987
# val_prod          95180.9
# qtd_pecas              99
# dtype: object

# %%
mes = df.groupby('num_mes')

# %% [markdown]
# df1.head()

# %%
mes2=mes.mean()

# %%
mes2
# Out:
#          num_ano   cod_cliente      cod_prod    val_prod  qtd_pecas
# num_mes
# 1         2017.0  2.718104e+07  8.067067e+07  817.793982   1.150421
# 2         2017.0  2.686038e+07  8.292570e+07  841.141212   1.122409
# 3         2017.0  2.696477e+07  8.406414e+07  846.516694   1.126491
# 4         2017.0  2.711205e+07  8.447667e+07  817.507498   1.138627
# 5         2017.0  2.725647e+07  8.560516e+07  836.593739   1.141079
# 6         2017.0  2.743056e+07  8.788522e+07  857.873803   1.152050
# 7         2017.0  2.760544e+07  8.823963e+07  837.759249   1.131063
# 8         2017.0  2.782973e+07  8.859815e+07  844.905047   1.124835
# 9         2017.0  2.800934e+07  9.027411e+07  803.811157   1.106330
# 10        2017.0  2.826054e+07  9.277358e+07  816.844987   1.097545
# 11        2017.0  2.854282e+07  9.469132e+07  847.684462   1.133665
# 12        2017.0  2.874859e+07  9.464497e+07  783.172568   1.104997

# %%
sns.barplot(x='num_mes',y='val_prod',data=df)

# %%
sns.barplot(x='num_mes',y='qtd_pecas',data=df, palette="rocket")

# %%
sns.barplot(x='num_mes',y='qtd_pecas',data=df, palette="rocket")

# %%
mes.max()
# Out:
#          dat_compra  num_ano  cod_cliente   cod_prod  val_prod  qtd_pecas
# num_mes
# 1        31/01/2017     2017     35753886  141080645  73758.66       50.0
# 2        28/02/2017     2017     35753754  141080645  70070.73       40.0
# 3        31/03/2017     2017     35753682  141087987  64698.89       48.0
# 4        30/04/2017     2017     35753859  141087987  70070.73       46.0
# 5        31/05/2017     2017     35753888  141087987  95180.95       99.0
# 6        30/06/2017     2017     35753888  141004105  70070.73       90.0
# 7        31/07/2017     2017     35753789  141087987  53404.43       60.0
# 8        31/08/2017     2017     35753880  141087987  70070.73       50.0
# 9        30/09/2017     2017     35753886  141024628  53404.43       50.0
# 10       31/10/2017     2017     35753880  141012228  70070.73       45.0
# 11       30/11/2017     2017     35753741  141087884  64766.54       42.0
# 12       07/12/2017     2017     35753749  141023086  43909.14       36.0

# %%
mes['val_prod'].plot()
# Out:
# num_mes
# 1     AxesSubplot(0.125,0.125;0.775x0.755)
# 2     AxesSubplot(0.125,0.125;0.775x0.755)
# 3     AxesSubplot(0.125,0.125;0.775x0.755)
# 4     AxesSubplot(0.125,0.125;0.775x0.755)
# 5     AxesSubplot(0.125,0.125;0.775x0.755)
# 6     AxesSubplot(0.125,0.125;0.775x0.755)
# 7     AxesSubplot(0.125,0.125;0.775x0.755)
# 8     AxesSubplot(0.125,0.125;0.775x0.755)
# 9     AxesSubplot(0.125,0.125;0.775x0.755)
# 10    AxesSubplot(0.125,0.125;0.775x0.755)
# 11    AxesSubplot(0.125,0.125;0.775x0.755)
# 12    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: val_prod, dtype: object

# %%
df["num_mes"].plot.hist(bins=30, edgecolor='black')

# %%
df.plot.scatter(x='qtd_pecas', y='val_prod',size=10)
sns.set_style('white')

# %%
sns.jointplot(x='qtd_pecas', y='val_prod',data=df)
# Out:
# C:\Users\Bruno\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Bruno\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(10,12))
sns.jointplot(x='qtd_pecas', y='val_prod',data=df)
# Out:
# C:\Users\Bruno\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Bruno\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.countplot(x='num_mes',data=df,hue='flg_mkt_place',palette='viridis')

# To relocate the legend
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
sns.jointplot(x='qtd_pecas', y='val_prod',data=df,size=10)
# Out:
# C:\Users\Bruno\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Bruno\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df2=df[(df['num_mes']==10)]

# %%
plt.figure(figsize=(30,6))
sns.countplot(x='cod_depto',data=df,palette='viridis')

# To relocate the legend
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# No handles with labels found to put in legend.

# %%
sns.set_style('white')
sns.lmplot('qtd_pecas','val_prod',data=df, hue='flg_mkt_place',
           palette='coolwarm',size=6,aspect=1,fit_reg=False)

# %%
sns.set_style('dark')
sns.lmplot('qtd_pecas','val_prod',data=df, hue='cod_depto',
           palette='coolwarm',size=6,aspect=1,fit_reg=False)

# %%
sns.countplot(x='flg_mkt_place',data=df[df['num_mes']==12])

# %%
sns.countplot(x='num_mes',data=df)

# %%
sns.scatterplot(x="distance", y="orbital_period",
                     hue="year", size="mass",
                     palette=cmap, sizes=(10, 200),
                     data=planets)
